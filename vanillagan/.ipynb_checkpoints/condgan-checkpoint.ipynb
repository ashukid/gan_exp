# %%
# stretching the cells
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))

# cuda settings
import os
import tensorflow as tf
os.environ["CUDA_VISIBLE_DEVICES"]="0"
os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"
gpu_options = tf.GPUOptions(per_process_gpu_memory_fraction=0.50)
# Out:
# <style>.container { width:100% !important; }</style>
# /usr/local/lib/python3.5/dist-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
from tensorflow.examples.tutorials.mnist import input_data
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
mnist = input_data.read_data_sets("./MNIST",one_hot=True)
# Out:
# WARNING:tensorflow:From <ipython-input-3-8826ea3cf231>:1: read_data_sets (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use alternatives such as official/mnist/dataset.py from tensorflow/models.
# WARNING:tensorflow:From /usr/local/lib/python3.5/dist-packages/tensorflow/contrib/learn/python/learn/datasets/mnist.py:260: maybe_download (from tensorflow.contrib.learn.python.learn.datasets.base) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please write your own downloading logic.
# WARNING:tensorflow:From /usr/local/lib/python3.5/dist-packages/tensorflow/contrib/learn/python/learn/datasets/mnist.py:262: extract_images (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use tf.data to implement this functionality.
# Extracting ./MNIST/train-images-idx3-ubyte.gz
# WARNING:tensorflow:From /usr/local/lib/python3.5/dist-packages/tensorflow/contrib/learn/python/learn/datasets/mnist.py:267: extract_labels (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use tf.data to implement this functionality.
# Extracting ./MNIST/train-labels-idx1-ubyte.gz
# WARNING:tensorflow:From /usr/local/lib/python3.5/dist-packages/tensorflow/contrib/learn/python/learn/datasets/mnist.py:110: dense_to_one_hot (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use tf.one_hot on tensors.
# Extracting ./MNIST/t10k-images-idx3-ubyte.gz
# Extracting ./MNIST/t10k-labels-idx1-ubyte.gz
# WARNING:tensorflow:From /usr/local/lib/python3.5/dist-packages/tensorflow/contrib/learn/python/learn/datasets/mnist.py:290: DataSet.__init__ (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use alternatives such as official/mnist/dataset.py from tensorflow/models.

# %%
plt.imshow(mnist.train.images[100].reshape(28,28))

# %%
# wil take a random noise (z) and return the reconstructed image
def GN(z,y,reuse=None):
    
    newz = tf.concat(axis=1,values=[z,y])
    with tf.variable_scope('gen',reuse=reuse):
        layer1 = tf.layers.dense(newz,256,activation=tf.nn.relu)
        layer2 = tf.layers.dense(layer1,512,activation=tf.nn.relu)
        output = tf.layers.dense(layer2,784,activation=tf.nn.tanh)

        return output

# %%
def DN(X,y,reuse=None):
    
    newX = tf.concat(axis=1,values=[X,y])
    with tf.variable_scope('dis',reuse=reuse):
        layer1 = tf.layers.dense(X,256,activation=tf.nn.relu)
        layer2 = tf.layers.dense(layer1,128,activation=tf.nn.relu)
        output = tf.layers.dense(layer2,1)

        return output

# %%
with tf.name_scope('placeholders'):
    real_image = tf.placeholder(tf.float32,shape=(None,784))
    z = tf.placeholder(tf.float32,shape=(None,100))
    y = tf.placeholder(tf.float32,shape=(None,10))

# %%
with tf.name_scope('logits'):
    fake_image = GN(z,y)

    real_logit = DN(real_image,y)
    fake_logit = DN(fake_image,y,reuse=True)

# %%
with tf.name_scope('losses'):
    real_loss = tf.reduce_mean(tf.nn.sigmoid_cross_entropy_with_logits(logits=real_logit,labels=tf.ones_like(real_logit)*0.9))
    fake_loss = tf.reduce_mean(tf.nn.sigmoid_cross_entropy_with_logits(logits=fake_logit,labels=tf.zeros_like(fake_logit)))
    
    dloss = real_loss+fake_loss
    gloss = tf.reduce_mean(tf.nn.sigmoid_cross_entropy_with_logits(logits=fake_logit,labels=tf.ones_like(fake_logit)*0.9))

# %%
with tf.name_scope('varaibles'):
    allvars = tf.trainable_variables()
    dvars = [var for var in allvars if 'dis' in var.name]
    gvars = [var for var in allvars if 'gen' in var.name]

# %%
with tf.variable_scope('optimizer',tf.AUTO_REUSE):
    
    doptimizer = tf.train.AdamOptimizer(learning_rate=0.0001).minimize(dloss,var_list=dvars)
    goptimizer = tf.train.AdamOptimizer(learning_rate=0.0001).minimize(gloss,var_list=gvars)

# %%
batch_size = 100
epoch = 500
generated_images=[]

# %%
# training.. 

with tf.Session(config=tf.ConfigProto(gpu_options=gpu_options)) as sess:
#     saver = tf.train.Saver()
    sess.run(tf.global_variables_initializer())
    for epoch in range(epoch):
        
        for i in range(mnist.train.num_examples//batch_size):
        #for i in range(1):
            
            batch_data = mnist.train.next_batch(batch_size=batch_size)
            ximage = batch_data[0].reshape((batch_size,784))
            xlabel = batch_data[1].reshape((batch_size,10))
            
            xsample = np.random.uniform(-1,1,size=(batch_size,100))
            sess.run(doptimizer,feed_dict={real_image:ximage,z:xsample,y:xlabel})
            sess.run(goptimizer,feed_dict={z:xsample,y:xlabel})
            if(i%500==0 and epoch%10==0):
                l1 = sess.run(dloss,feed_dict={real_image:ximage,z:xsample,y:xlabel})
                l2 = sess.run(gloss,feed_dict={z:xsample,y:xlabel})
                print("after {} losses : Descriptor : {} Generator : {}\n".format(i,l1,l2))
        
        print("On epoch {}".format(epoch))
        cur_sample = np.random.uniform(-1,1,size=(1,100))
        one_hot = np.full(shape=(1,10),fill_value=1) # this is to condition the generator
        gen_sample = sess.run(GN(z,y,reuse=True),feed_dict={z:cur_sample,y:one_hot})
        generated_images.append(gen_sample)
    # saver.save(sess,"./gan/mnist_gan_500.ckpt")
# Out:
# after 0 losses : Descriptor : 1.4607096910476685 Generator : 0.6379136443138123
#
# after 500 losses : Descriptor : 0.788947582244873 Generator : 1.448356032371521
#
# On epoch 0
# On epoch 1
# On epoch 2
# On epoch 3
# On epoch 4
# On epoch 5
# On epoch 6
# On epoch 7
# On epoch 8
# On epoch 9
# after 0 losses : Descriptor : 0.4213573634624481 Generator : 3.2239246368408203
#
# after 500 losses : Descriptor : 0.440451979637146 Generator : 3.1298232078552246
#
# On epoch 10
# On epoch 11
# On epoch 12
# On epoch 13
# On epoch 14
# On epoch 15
# On epoch 16
# On epoch 17
# On epoch 18
# On epoch 19
# after 0 losses : Descriptor : 0.36988365650177 Generator : 3.9858384132385254
#
# after 500 losses : Descriptor : 0.41261380910873413 Generator : 3.5874319076538086
#
# On epoch 20
# On epoch 21
# On epoch 22
# On epoch 23
# On epoch 24
# On epoch 25
# On epoch 26
# On epoch 27
# On epoch 28
# On epoch 29
# after 0 losses : Descriptor : 0.39234936237335205 Generator : 4.110661506652832
#
# after 500 losses : Descriptor : 0.4051518738269806 Generator : 3.9351425170898438
#
# On epoch 30
# On epoch 31
# On epoch 32
# On epoch 33
# On epoch 34
# On epoch 35
# On epoch 36
# On epoch 37
# On epoch 38
# On epoch 39
# after 0 losses : Descriptor : 0.45061779022216797 Generator : 2.8201839923858643
#
# after 500 losses : Descriptor : 0.4615681767463684 Generator : 3.37416934967041
#
# On epoch 40
# On epoch 41
# On epoch 42
# On epoch 43
# On epoch 44
# On epoch 45
# On epoch 46
# On epoch 47
# On epoch 48
# On epoch 49
# after 0 losses : Descriptor : 0.5460838675498962 Generator : 3.125610589981079
#
# after 500 losses : Descriptor : 0.49170148372650146 Generator : 3.221820592880249
#
# On epoch 50
# On epoch 51
# On epoch 52
# On epoch 53
# On epoch 54
# On epoch 55
# On epoch 56
# On epoch 57
# On epoch 58
# On epoch 59
# after 0 losses : Descriptor : 0.7384958267211914 Generator : 2.4421424865722656
#
# after 500 losses : Descriptor : 0.621123731136322 Generator : 2.4905266761779785
#
# On epoch 60
# On epoch 61
# On epoch 62
# On epoch 63
# On epoch 64
# On epoch 65
# On epoch 66
# On epoch 67
# On epoch 68
# On epoch 69
# after 0 losses : Descriptor : 0.6998353004455566 Generator : 2.321892499923706
#
# after 500 losses : Descriptor : 0.6905634999275208 Generator : 2.0988786220550537
#
# On epoch 70
# On epoch 71
# On epoch 72
# On epoch 73
# On epoch 74
# On epoch 75
# On epoch 76
# On epoch 77
# On epoch 78
# On epoch 79
# after 0 losses : Descriptor : 0.6800041794776917 Generator : 2.1871979236602783
#
# after 500 losses : Descriptor : 0.7201329469680786 Generator : 2.299715995788574
#
# On epoch 80
# On epoch 81
# On epoch 82
# On epoch 83
# On epoch 84
# On epoch 85
# On epoch 86
# On epoch 87
# On epoch 88
# On epoch 89
# after 0 losses : Descriptor : 0.8047059178352356 Generator : 1.8278902769088745
#
# after 500 losses : Descriptor : 0.846577525138855 Generator : 1.7102121114730835
#
# On epoch 90
# On epoch 91
# On epoch 92
# On epoch 93
# On epoch 94
# On epoch 95
# On epoch 96
# On epoch 97
# On epoch 98
# On epoch 99
# after 0 losses : Descriptor : 0.9456440806388855 Generator : 1.5735441446304321
#
# after 500 losses : Descriptor : 1.017629623413086 Generator : 1.7073745727539062
#
# On epoch 100
# On epoch 101
# On epoch 102
# On epoch 103
# On epoch 104
# On epoch 105
# On epoch 106
# On epoch 107
# On epoch 108
# On epoch 109
# after 0 losses : Descriptor : 0.9463640451431274 Generator : 1.5411887168884277
#
# after 500 losses : Descriptor : 0.9115997552871704 Generator : 1.5594596862792969
#
# On epoch 110
# On epoch 111
# On epoch 112
# On epoch 113
# On epoch 114
# On epoch 115
# On epoch 116
# On epoch 117
# On epoch 118
# On epoch 119
# after 0 losses : Descriptor : 0.9456179141998291 Generator : 1.7031739950180054
#
# after 500 losses : Descriptor : 0.9747755527496338 Generator : 1.5702483654022217
#
# On epoch 120
# On epoch 121
# On epoch 122
# On epoch 123
# On epoch 124
# On epoch 125
# On epoch 126
# On epoch 127
# On epoch 128
# On epoch 129
# after 0 losses : Descriptor : 0.9695922136306763 Generator : 1.3860464096069336
#
# after 500 losses : Descriptor : 0.9959176778793335 Generator : 1.5049586296081543
#
# On epoch 130
# On epoch 131
# On epoch 132
# On epoch 133
# On epoch 134
# On epoch 135
# On epoch 136
# On epoch 137
# On epoch 138
# On epoch 139
# after 0 losses : Descriptor : 1.1056872606277466 Generator : 1.401524543762207
#
# after 500 losses : Descriptor : 0.9505561590194702 Generator : 1.4266228675842285
#
# On epoch 140
# On epoch 141
# On epoch 142
# On epoch 143
# On epoch 144
# On epoch 145
# On epoch 146
# On epoch 147
# On epoch 148
# On epoch 149
# after 0 losses : Descriptor : 0.916445791721344 Generator : 1.6730751991271973
#
# after 500 losses : Descriptor : 0.9206812381744385 Generator : 1.5844316482543945
#
# On epoch 150
# On epoch 151
# On epoch 152
# On epoch 153
# On epoch 154
# On epoch 155
# On epoch 156
# On epoch 157
# On epoch 158
# On epoch 159
# after 0 losses : Descriptor : 0.9306677579879761 Generator : 1.5713293552398682
#
# after 500 losses : Descriptor : 0.9099857211112976 Generator : 1.5616766214370728
#
# On epoch 160
# On epoch 161
# On epoch 162
# On epoch 163
# On epoch 164
# On epoch 165
# On epoch 166
# On epoch 167
# On epoch 168
# On epoch 169
# after 0 losses : Descriptor : 0.9576484560966492 Generator : 1.668623685836792
#
# after 500 losses : Descriptor : 0.8641914129257202 Generator : 1.6360681056976318
#
# On epoch 170
# On epoch 171
# On epoch 172
# On epoch 173
# On epoch 174
# On epoch 175
# On epoch 176
# On epoch 177
# On epoch 178
# On epoch 179
# after 0 losses : Descriptor : 0.9269795417785645 Generator : 1.6587414741516113
#
# after 500 losses : Descriptor : 0.8693944215774536 Generator : 1.6601635217666626
#
# On epoch 180
# On epoch 181
# On epoch 182
# On epoch 183
# On epoch 184
# On epoch 185
# On epoch 186
# On epoch 187
# On epoch 188
# On epoch 189
# after 0 losses : Descriptor : 1.0827016830444336 Generator : 1.5717626810073853
#
# after 500 losses : Descriptor : 0.7762444019317627 Generator : 1.728413701057434
#
# On epoch 190
# On epoch 191
# On epoch 192
# On epoch 193
# On epoch 194
# On epoch 195
# On epoch 196
# On epoch 197
# On epoch 198
# On epoch 199
# after 0 losses : Descriptor : 0.9107409715652466 Generator : 1.5352492332458496
#
# after 500 losses : Descriptor : 0.877962589263916 Generator : 1.6548305749893188
#
# On epoch 200
# On epoch 201
# On epoch 202
# On epoch 203
# On epoch 204
# On epoch 205
# On epoch 206
# On epoch 207
# On epoch 208
# On epoch 209
# after 0 losses : Descriptor : 0.8666618466377258 Generator : 1.657906174659729
#
# after 500 losses : Descriptor : 0.9775450229644775 Generator : 1.4092923402786255
#
# On epoch 210
# On epoch 211
# On epoch 212
# On epoch 213
# On epoch 214
# On epoch 215
# On epoch 216
# On epoch 217
# On epoch 218
# On epoch 219
# after 0 losses : Descriptor : 0.9272916316986084 Generator : 1.5453568696975708
#
# after 500 losses : Descriptor : 0.8890060782432556 Generator : 1.5779151916503906
#
# On epoch 220
# On epoch 221
# On epoch 222
# On epoch 223
# On epoch 224
# On epoch 225
# On epoch 226
# On epoch 227
# On epoch 228
# On epoch 229
# after 0 losses : Descriptor : 0.8993570804595947 Generator : 1.7308067083358765
#
# after 500 losses : Descriptor : 0.8652719259262085 Generator : 1.5568314790725708
#
# On epoch 230
# On epoch 231
# On epoch 232
# On epoch 233
# On epoch 234
# On epoch 235
# On epoch 236
# On epoch 237
# On epoch 238
# On epoch 239
# after 0 losses : Descriptor : 0.8926974534988403 Generator : 1.5566720962524414
#
# after 500 losses : Descriptor : 0.8792622089385986 Generator : 1.7082953453063965
#
# On epoch 240
# On epoch 241
# On epoch 242
# On epoch 243
# On epoch 244
# On epoch 245
# On epoch 246
# On epoch 247
# On epoch 248
# On epoch 249
# after 0 losses : Descriptor : 0.8344557285308838 Generator : 1.7578799724578857
#
# after 500 losses : Descriptor : 0.766712486743927 Generator : 1.8968169689178467
#
# On epoch 250
# On epoch 251
# On epoch 252
# On epoch 253
# On epoch 254
# On epoch 255
# On epoch 256
# On epoch 257
# On epoch 258
# On epoch 259
# after 0 losses : Descriptor : 0.8035942912101746 Generator : 1.8707388639450073
#
# after 500 losses : Descriptor : 1.032361388206482 Generator : 1.5849920511245728
#
# On epoch 260
# On epoch 261
# On epoch 262
# On epoch 263
# On epoch 264
# On epoch 265
# On epoch 266
# On epoch 267
# On epoch 268
# On epoch 269
# after 0 losses : Descriptor : 0.8761091232299805 Generator : 1.6736822128295898
#
# after 500 losses : Descriptor : 0.9091768264770508 Generator : 1.624952793121338
#
# On epoch 270
# On epoch 271
# On epoch 272
# On epoch 273
# On epoch 274
# On epoch 275
# On epoch 276
# On epoch 277
# On epoch 278
# On epoch 279
# after 0 losses : Descriptor : 0.8128825426101685 Generator : 1.8077445030212402
#
# after 500 losses : Descriptor : 0.8707602024078369 Generator : 1.7641557455062866
# On epoch 280
# On epoch 281
# On epoch 282
# On epoch 283
# On epoch 284
# On epoch 285
# On epoch 286
# On epoch 287
# On epoch 288
# On epoch 289
# after 0 losses : Descriptor : 0.8163748979568481 Generator : 1.982121229171753
#
# after 500 losses : Descriptor : 0.8437327742576599 Generator : 1.9039313793182373
#
# On epoch 290
# On epoch 291
# On epoch 292
# On epoch 293
# On epoch 294
# On epoch 295
# On epoch 296
# On epoch 297
# On epoch 298
# On epoch 299
# after 0 losses : Descriptor : 0.9074358940124512 Generator : 1.763118028640747
#
# after 500 losses : Descriptor : 0.8015854954719543 Generator : 1.8417408466339111
#
# On epoch 300
# On epoch 301
# On epoch 302
# On epoch 303
# On epoch 304
# On epoch 305
# On epoch 306
# On epoch 307
# On epoch 308
# On epoch 309
# after 0 losses : Descriptor : 0.9726629257202148 Generator : 1.484920620918274
#
# after 500 losses : Descriptor : 0.9204007983207703 Generator : 1.6701949834823608
#
# On epoch 310
# On epoch 311
# On epoch 312
# On epoch 313
# On epoch 314
# On epoch 315
# On epoch 316
# On epoch 317
# On epoch 318
# On epoch 319
# after 0 losses : Descriptor : 0.884833574295044 Generator : 1.6533572673797607
#
# after 500 losses : Descriptor : 0.8987439870834351 Generator : 1.6943116188049316
#
# On epoch 320
# On epoch 321
# On epoch 322
# On epoch 323
# On epoch 324
# On epoch 325
# On epoch 326
# On epoch 327
# On epoch 328
# On epoch 329
# after 0 losses : Descriptor : 0.8900705575942993 Generator : 1.7512283325195312
#
# after 500 losses : Descriptor : 0.8530250191688538 Generator : 1.7593998908996582
#
# On epoch 330
# On epoch 331
# On epoch 332
# On epoch 333
# On epoch 334
# On epoch 335
# On epoch 336
# On epoch 337
# On epoch 338
# On epoch 339
# after 0 losses : Descriptor : 0.9617393016815186 Generator : 1.619832158088684
#
# after 500 losses : Descriptor : 0.9913905262947083 Generator : 1.6699767112731934
#
# On epoch 340
# On epoch 341
# On epoch 342
# On epoch 343
# On epoch 344
# On epoch 345
# On epoch 346
# On epoch 347
# On epoch 348
# On epoch 349
# after 0 losses : Descriptor : 0.8601986765861511 Generator : 1.6340162754058838
#
# after 500 losses : Descriptor : 0.895278811454773 Generator : 1.6531202793121338
#
# On epoch 350
# On epoch 351
# On epoch 352
# On epoch 353
# On epoch 354
# On epoch 355
# On epoch 356
# On epoch 357
# On epoch 358
# On epoch 359
# after 0 losses : Descriptor : 0.833575963973999 Generator : 1.7079168558120728
#
# after 500 losses : Descriptor : 0.8969956636428833 Generator : 1.8370811939239502
#
# On epoch 360
# On epoch 361
# On epoch 362
# On epoch 363
# On epoch 364
# On epoch 365
# On epoch 366
# On epoch 367
# On epoch 368
# On epoch 369
# after 0 losses : Descriptor : 0.9203487634658813 Generator : 1.8442970514297485
#
# after 500 losses : Descriptor : 0.8561791181564331 Generator : 1.707679033279419
#
# On epoch 370
# On epoch 371
# On epoch 372
# On epoch 373
# On epoch 374
# On epoch 375
# On epoch 376
# On epoch 377
# On epoch 378
# On epoch 379
# after 0 losses : Descriptor : 0.8353078365325928 Generator : 1.7799041271209717
#
# after 500 losses : Descriptor : 0.9168779850006104 Generator : 1.7166980504989624
#
# On epoch 380
# On epoch 381
# On epoch 382
# On epoch 383
# On epoch 384
# On epoch 385
# On epoch 386
# On epoch 387
# On epoch 388
# On epoch 389
# after 0 losses : Descriptor : 0.8895808458328247 Generator : 1.5493983030319214
#
# after 500 losses : Descriptor : 0.9120660424232483 Generator : 1.6697170734405518
#
# On epoch 390
# On epoch 391
# On epoch 392
# On epoch 393
# On epoch 394
# On epoch 395
# On epoch 396
# On epoch 397
# On epoch 398
# On epoch 399
# after 0 losses : Descriptor : 0.8656107187271118 Generator : 1.7850008010864258
#
# after 500 losses : Descriptor : 0.9658171534538269 Generator : 1.782832384109497
#
# On epoch 400
# On epoch 401
# On epoch 402
# On epoch 403
# On epoch 404
# On epoch 405
# On epoch 406
# On epoch 407
# On epoch 408
# On epoch 409
# after 0 losses : Descriptor : 0.9301069378852844 Generator : 1.6019845008850098
#
# after 500 losses : Descriptor : 0.9303951859474182 Generator : 1.6567566394805908
#
# On epoch 410
# On epoch 411
# On epoch 412
# On epoch 413
# On epoch 414
# On epoch 415
# On epoch 416
# On epoch 417
# On epoch 418
# On epoch 419
# after 0 losses : Descriptor : 0.950212299823761 Generator : 1.493503451347351
#
# after 500 losses : Descriptor : 0.9465086460113525 Generator : 1.6273810863494873
#
# On epoch 420
# On epoch 421
# On epoch 422
# On epoch 423
# On epoch 424
# On epoch 425
# On epoch 426
# On epoch 427
# On epoch 428
# On epoch 429
# after 0 losses : Descriptor : 0.9700299501419067 Generator : 1.910902976989746
#
# after 500 losses : Descriptor : 0.9109600186347961 Generator : 1.5782183408737183
#
# On epoch 430
# On epoch 431
# On epoch 432
# On epoch 433
# On epoch 434
# On epoch 435
# On epoch 436
# On epoch 437
# On epoch 438
# On epoch 439
# after 0 losses : Descriptor : 0.9394745826721191 Generator : 1.6655075550079346
#
# after 500 losses : Descriptor : 0.8734563589096069 Generator : 1.713984727859497
#
# On epoch 440
# On epoch 441
# On epoch 442
# On epoch 443
# On epoch 444
# On epoch 445
# On epoch 446
# On epoch 447
# On epoch 448
# On epoch 449
# after 0 losses : Descriptor : 0.8847464323043823 Generator : 1.9105111360549927
#
# after 500 losses : Descriptor : 0.893878698348999 Generator : 1.7949451208114624
#
# On epoch 450
# On epoch 451
# On epoch 452
# On epoch 453
# On epoch 454
# On epoch 455
# On epoch 456
# On epoch 457
# On epoch 458
# On epoch 459
# after 0 losses : Descriptor : 0.9262916445732117 Generator : 1.6571075916290283
#
# after 500 losses : Descriptor : 0.91489177942276 Generator : 1.6003127098083496
#
# On epoch 460
# On epoch 461
# On epoch 462
# On epoch 463
# On epoch 464
# On epoch 465
# On epoch 466
# On epoch 467
# On epoch 468
# On epoch 469
# after 0 losses : Descriptor : 0.8799755573272705 Generator : 1.8239450454711914
#
# after 500 losses : Descriptor : 0.8693109154701233 Generator : 1.7124295234680176
#
# On epoch 470
# On epoch 471
# On epoch 472
# On epoch 473
# On epoch 474
# On epoch 475
# On epoch 476
# On epoch 477
# On epoch 478
# On epoch 479
# after 0 losses : Descriptor : 0.9514460563659668 Generator : 1.724135398864746
#
# after 500 losses : Descriptor : 0.9670532941818237 Generator : 1.491184115409851
#
# On epoch 480
# On epoch 481
# On epoch 482
# On epoch 483
# On epoch 484
# On epoch 485
# On epoch 486
# On epoch 487
# On epoch 488
# On epoch 489
# after 0 losses : Descriptor : 0.9335809946060181 Generator : 1.4095724821090698
#
# after 500 losses : Descriptor : 0.8721449971199036 Generator : 1.6662544012069702
#
# On epoch 490
# On epoch 491
# On epoch 492
# On epoch 493
# On epoch 494
# On epoch 495
# On epoch 496
# On epoch 497
# On epoch 498
# On epoch 499

# %%
# previously generated images conditioned on 1
plt.figure()
plt.subplot(3,3,1)
plt.imshow(generated_images[32].reshape(28,28))
plt.subplot(3,3,2)
plt.imshow(generated_images[83].reshape(28,28))
plt.subplot(3,3,3)
plt.imshow(generated_images[283].reshape(28,28))
plt.subplot(3,3,4)
plt.imshow(generated_images[399].reshape(28,28))
plt.subplot(3,3,5)
plt.imshow(generated_images[400].reshape(28,28))
plt.subplot(3,3,6)
plt.imshow(generated_images[450].reshape(28,28))
plt.subplot(3,3,7)
plt.imshow(generated_images[469].reshape(28,28))
plt.subplot(3,3,8)
plt.imshow(generated_images[489].reshape(28,28))
plt.subplot(3,3,9)
plt.imshow(generated_images[499].reshape(28,28))
